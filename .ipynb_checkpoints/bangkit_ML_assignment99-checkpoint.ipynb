# %% [markdown]
# # Denpasar Weather Forecasting with TensorFlow

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

mpl.rcParams['figure.figsize'] = (12, 5)
mpl.rcParams['axes.grid'] = False

# %% [markdown]
# ## The weather dataset
#
# Data collected between 1990-2020 every 10 minutes

# %%
usecols = ['dt_iso', 'temp', 'temp_min', 'temp_max', 'pressure', 'humidity', 'wind_speed', 'wind_deg', 
           'clouds_all', 'weather_main', 'weather_description']
df = pd.read_csv('openweatherdata-denpasar-1990-2020v0.1.csv', parse_dates=True, index_col='dt_iso', usecols=usecols)
df.head()
# Out:
#                       temp  temp_min  temp_max  pressure  humidity  \
# dt_iso
# 1990-01-01 00:00:00  25.82     25.82     25.82    1010.0        86
# 1990-01-01 01:00:00  26.20     26.20     26.20    1011.0        84
# 1990-01-01 02:00:00  26.45     26.45     26.45    1011.0        84
# 1990-01-01 03:00:00  26.80     26.80     26.80    1011.0        82
# 1990-01-01 04:00:00  27.04     27.04     27.04    1010.0        82
#
#                      wind_speed  wind_deg  clouds_all weather_main  \
# dt_iso
# 1990-01-01 00:00:00        1.36       225          98         Rain
# 1990-01-01 01:00:00        2.09       247          91         Rain
# 1990-01-01 02:00:00        2.44       262          94         Rain
# 1990-01-01 03:00:00        2.29       271          94         Rain
# 1990-01-01 04:00:00        1.71       274          76       Clouds
#
#                     weather_description
# dt_iso
# 1990-01-01 00:00:00          light rain
# 1990-01-01 01:00:00          light rain
# 1990-01-01 02:00:00          light rain
# 1990-01-01 03:00:00          light rain
# 1990-01-01 04:00:00       broken clouds

# %%
df.shape
# Out:
# (264924, 10)

# %% [markdown]
# **Data Split Function**

# %%
# Split the data by percentage
def num_data_train(percentage, data_length):
    num_data = percentage / 100 * data_length
    return int(num_data)

# %% [markdown]
# ## Forecast a univariate time series

# %% [markdown]
# **Split the data**

# %%
TRAIN_SPLIT = num_data_train(70, df.shape[0]) # Split 70% of the data for training
tf.random.set_seed(13) # Setting seed to ensure reproducibility
print('Length of Data Train: {}'.format(TRAIN_SPLIT))
# Out:
# Length of Data Train: 185446

# %%
# Train a model using a single feature (temperature)
dt_temp = df['temp']
# dt_temp.index = df['dt_iso']
dt_temp.tail()
# Out:
# dt_iso
# 2020-01-07 19:00:00    27.0
# 2020-01-07 20:00:00    27.0
# 2020-01-07 21:00:00    28.0
# 2020-01-07 22:00:00    28.0
# 2020-01-07 23:00:00    28.0
# Name: temp, dtype: float64

# %%
dt_temp.plot(subplots=True)
plt.show()

# %%
# Convert the dataframe into numpy array
array_temp = dt_temp.values
print(array_temp[:10]) # Print 10 elements for checking
# Out:
# [25.82 26.2  26.45 26.8  27.04 27.23 27.32 27.29 27.34 27.23]

# %%
# Scaling the features
array_temp_mean = array_temp[:TRAIN_SPLIT].mean()
array_temp_std = array_temp[:TRAIN_SPLIT].std()
print('Training Data Mean: {}'.format(array_temp_mean))
print('\nTraining Data Std.Dev: {}'.format(array_temp_std))
# Out:
# Training Data Mean: 27.1836268239811
#
# Training Data Std.Dev: 1.9980058874922433

# %%
# Standardize the data
array_temp = (array_temp - array_temp_mean) / array_temp_std
print(array_temp)
# Out:
# [-0.6824939  -0.49230427 -0.36717951 ...  0.40859398  0.40859398
#   0.40859398]

# %%
# create a function that return the time windows for the model to train on
def univariate_data(dataset, start_index, end_index, history_size, target_size):
    data = []
    labels = []
    
    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset) - target_size
        
    for i in range(start_index, end_index):
        indices = range(i - history_size, i)
        # Reshape data from (history_size,) to (history_size, 1)
        data.append(np.reshape(dataset[indices], (history_size, 1)))
        labels.append(dataset[i+target_size])
        
    return np.array(data), np.array(labels)

# %% [markdown]
# In this part, the model will be given the last **`n`** recorded temperature observation, and needs to learn to predict the temperature at the next **`m`** time step.

# %%
# Create the univariate model
data_past_history = 30 # number of last recorded data (n)
data_future_target = 0 # number of time step (m)

x_train, y_train = univariate_data(array_temp, 0, TRAIN_SPLIT, data_past_history, data_future_target)
x_val, y_val = univariate_data(array_temp, TRAIN_SPLIT, None, data_past_history, data_future_target)

print('Single window of past history:')
print(x_train[0])
print('\n Target temperature to predict:')
print(y_train[0])
# Out:
# Single window of past history:
# [[-0.6824939 ]
#  [-0.49230427]
#  [-0.36717951]
#  [-0.19200485]
#  [-0.07188509]
#  [ 0.02320973]
#  [ 0.06825464]
#  [ 0.05323967]
#  [ 0.07826462]
#  [ 0.02320973]
#  [ 0.10829456]
#  [ 0.07325963]
#  [-0.19700984]
#  [-0.44725935]
#  [-0.56237413]
#  [-0.63244399]
#  [-0.63744898]
#  [-0.65246396]
#  [-0.69750887]
#  [-0.8326436 ]
#  [-1.01782824]
#  [-1.0428532 ]
#  [-1.03284321]
#  [-1.07788813]
#  [-1.01782824]
#  [-0.99280329]
#  [-0.96777834]
#  [-0.8326436 ]
#  [-0.85766856]
#  [-0.75256376]]
#
#  Target temperature to predict:
# -0.8076186532194914

# %%
def create_time_steps(length):
    return list(range(-length, 0))

# %%
def show_plot(plot_data, delta, title):
    labels = ['History', 'True Future', 'Model Prediction']
    marker = ['.-', 'rx', 'go']
    time_steps = create_time_steps(plot_data[0].shape[0])
    if delta:
        future = delta
    else:
        future = 0
        
    plt.title(title)
    for i, x in enumerate(plot_data):
        if i:
            plt.plot(future, plot_data[i], marker[i], markersize=10, label=labels[i])
        else:
            plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
       
    plt.legend()
    plt.xlim([time_steps[0], (future+5)*2])
    plt.xlabel('Time-Step')
    return plt

# %%
show_plot([x_train[0], y_train[0]], 0, 'Test Sample')
# Out:
# <module 'matplotlib.pyplot' from 'c:\\users\\rudyh\\documents\\python_code\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
from tensorflow.keras import layers
tf.keras.backend.clear_session()  # For easy reset of notebook state.

# Normal Sequential model
model_1 = tf.keras.models.Sequential([
    tf.keras.layers.Dense(16, input_shape=x_train.shape[-2:]), 
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1)
])

# Compare with simple LSTM Model, according to several sources LSTM is suitable for modeling time series data
model_2 = tf.keras.models.Sequential(
    [tf.keras.layers.LSTM(8, input_shape=x_train.shape[-2:]), 
    tf.keras.layers.Dense(1)
])
model_1.summary()
model_2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 30, 16)            32
# _________________________________________________________________
# dense_1 (Dense)              (None, 30, 16)            272
# _________________________________________________________________
# dense_2 (Dense)              (None, 30, 1)             17
# =================================================================
# Total params: 321
# Trainable params: 321
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 8)                 320
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 329
# Trainable params: 329
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Not worked yet
# model.compile(optimizer=tf.keras.optimizers.Adam(0.01),
#               loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
#               metrics=['accuracy'])

# Use simple parameter, need more explore in this area
model_1.compile(optimizer='adam', loss='mae')
model_2.compile(optimizer='adam', loss='mae')

# %% [markdown]
# **Further reading:**
#
#     1. https://stats.stackexchange.com/questions/153531/what-is-batch-size-in-neural-network
#     2. https://stackoverflow.com/questions/45943675/meaning-of-validation-steps-in-keras-sequential-fit-generator-parameter-list/45944225
#     3. https://stats.stackexchange.com/questions/181/how-to-choose-the-number-of-hidden-layers-and-nodes-in-a-feedforward-neural-netw

# %%
BATCH_SIZE = 256
BUFFER_SIZE = 10000

datatrain = tf.data.Dataset.from_tensor_slices((x_train, y_train))
datatrain = datatrain.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

dataval = tf.data.Dataset.from_tensor_slices((x_val, y_val))
dataval = dataval.batch(BATCH_SIZE).repeat()

# %%
# dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
# dataset = dataset.batch(32)

# val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))
# val_dataset = val_dataset.batch(32)

# %%
EPOCHS = 10
STEPS_PER_EPOCH = 200 # number of time steps
VALIDATION_STEPS = 50

# Train the model
model_1_history = model_1.fit(datatrain, epochs=EPOCHS, steps_per_epoch=STEPS_PER_EPOCH, validation_data=dataval, 
                      validation_steps=VALIDATION_STEPS)
model_2_history = model_2.fit(datatrain, epochs=EPOCHS, steps_per_epoch=STEPS_PER_EPOCH, validation_data=dataval, 
                      validation_steps=VALIDATION_STEPS)
# Out:
# Train for 200 steps, validate for 50 steps
# Epoch 1/10
# 200/200 [==============================] - 1s 7ms/step - loss: 0.6002 - val_loss: 0.7154
# Epoch 2/10
# 174/200 [=========================>....] - ETA: 0s - loss: 0.8205

# %%
def plot_train_history(history, title):
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    epochs = range(len(loss))
    
    plt.figure()
    
    plt.plot(epochs, loss, 'b', label='Training Loss')
    plt.plot(epochs, val_loss, 'r', label='Validation Loss')
    plt.title(title)
    plt.legend()
    
    plt.show()

# %%
plot_train_history(model_1_history, 'First Model Training and Validation Loss')
plot_train_history(model_2_history, 'Second Model Training and Validation Loss')

# %% [markdown]
# **The graph above indicates that the model performance was not really good because we only use single feature (temperature)**
# First model is not really clear whether it is overfit or underfit, but the second model clealy underfit. Second model need hyperparameter tuning or because it used only single feature.
#
# In the next section we will use multi-feature/multivariate forecasting.

# %% [markdown]
# Further readings:
#     1. https://developers.google.com/machine-learning/crash-course/descending-into-ml/training-and-loss
#     2. https://stackoverflow.com/questions/48226086/training-loss-and-validation-loss-in-deep-learning

# %% [markdown]
# # Multivariate Forecasting

# %%
# Exploratory Data Analysis

# %%
# df_multivariate = df.drop(['weather_main', 'weather_description'], axis=1)
df_multivariate = df[['temp', 'temp_min', 'temp_max', 'pressure', 'humidity']]
df_multivariate.head()

# %%
import seaborn as sns

sns.heatmap(df_multivariate.corr(), annot=True)
plt.show()

# %%
# Don't use data in 2020
df_multivariate = df_multivariate.loc['1990':'2019']
df_multivariate.tail()

# %%
# Convert the dataframe to numpy array
# df_multivariate = df_multivariate.drop('date', axis=1)
dt_multivariate = df_multivariate.values
print('Number of dataset: {}'.format(len(df_multivariate)))
print('10 samples of data: {}'.format(dt_multivariate[:10]))

# %%
#Normalizing the data using StandardScaler from sklearn, instead of using the conventional calculation like the above before
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
dt_multivariate = sc.fit_transform(dt_multivariate)
print('Normalized data:')
print(dt_multivariate[10])
print(dt_multivariate.shape)

# %% [markdown]
# ## Single Step Model
#
# In a single step setup, the model learns to predict a single point in the future based on history provided

# %%
def multivariate_data(dataset, target, start_index, end_index, history_size, target_size, step, single_step=False):
    data = []
    labels = []
    
    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset) - target_size
        
    for i in range(start_index, end_index):
        indices = range(i - history_size, i, step)
        data.append(dataset[indices])
        
        if single_step:
            labels.append(target[i+target_size])
        else:
            labels.append(target[i:i+target_size])
            
    return np.array(data), np.array(labels)

# %%
TRAIN_SPLIT = num_data_train(60, df.shape[0]) # Split

# %% [markdown]
# Use number of hours (**`past_history`**) of data to predict future (**`future_target`**) hourly temperature

# %% [markdown]
# Note:
#     - LSTMs expect 3D input, and it can be challenging to get your head around this the first time.
#     - LSTMs don’t like sequences of more than 200-400 time steps, so the data will need to be split into samples.

# %%
past_history = 168
future_target = 48
STEP = 24 # We can customize how many time steps that we want to use

x_train_single, y_train_single = multivariate_data(dt_multivariate, dt_multivariate[:, 1], 0, TRAIN_SPLIT, past_history, 
                                                   future_target, STEP, single_step=True)
x_val_single, y_val_single = multivariate_data(dt_multivariate, dt_multivariate[:, 1], TRAIN_SPLIT, None, past_history, 
                                               future_target, STEP, single_step=True)

# %%
print(len(x_train_single), len(y_train_single))
print(len(x_val_single), len(y_val_single))

# %%
# Test at a single data point
print('Single window of past history: {}'.format(x_train_single[0].shape))

# %%
train_data_single = tf.data.Dataset.from_tensor_slices((x_train_single, y_train_single))
train_data_single = train_data_single.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_single = tf.data.Dataset.from_tensor_slices((x_val_single, y_val_single))
val_data_single = val_data_single.batch(BATCH_SIZE).repeat()

# %%
print(x_train_single.shape, x_val_single.shape)
print()
print(y_train_single.shape, y_val_single.shape)

# %%
# Normal Sequential model
tf.keras.backend.clear_session()
single_step_model_1 = tf.keras.models.Sequential([
    tf.keras.layers.Dense(32, input_shape=x_train_single.shape[-2:]), 
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1)
])
single_step_model_1.compile(optimizer='sgd', loss='mae')

# 2 layer LSTM
single_step_model_2 = tf.keras.models.Sequential()
single_step_model_2.add(tf.keras.layers.LSTM(32, input_shape=x_train_single.shape[-2:]))
single_step_model_2.add(tf.keras.layers.Dense(32, activation='relu'))
single_step_model_2.add(tf.keras.layers.Dense(1))
single_step_model_2.compile(optimizer='sgd', loss='mae')

single_step_model_1.summary()
single_step_model_2.summary()

# %%
for x, y in val_data_single.take(1):
    print(single_step_model_1.predict(x).shape)
    print(single_step_model_2.predict(x).shape)
# Out:
# (256, 7, 1)
# (256, 1)

# %%
EPOCHS = 100 # 10
STEPS_PER_EPOCH = 500 # 200
VALIDATION_STEPS = 100 # 50
single_step_model_1_history = single_step_model_1.fit(train_data_single, epochs=EPOCHS, steps_per_epoch=STEPS_PER_EPOCH,
                                            validation_data=val_data_single, validation_steps=VALIDATION_STEPS)
single_step_model_2_history = single_step_model_2.fit(train_data_single, epochs=EPOCHS, steps_per_epoch=STEPS_PER_EPOCH,
                                            validation_data=val_data_single, validation_steps=VALIDATION_STEPS)
# Out:
# - 6s 12ms/step - loss: 0.5783 - val_loss: 0.5976
# Epoch 9/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5721 - val_loss: 0.5934
# Epoch 10/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.6010 - val_loss: 0.6165
# Epoch 11/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.6005 - val_loss: 0.5879
# Epoch 12/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5781 - val_loss: 0.5903
# Epoch 13/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5775 - val_loss: 0.5939
# Epoch 14/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5682 - val_loss: 0.5922
# Epoch 15/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5929 - val_loss: 0.6357
# Epoch 16/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.6050 - val_loss: 0.5851
# Epoch 17/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5802 - val_loss: 0.5891
# Epoch 18/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5769 - val_loss: 0.5894
# Epoch 19/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5682 - val_loss: 0.5913
# Epoch 20/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5848 - val_loss: 0.6541
# Epoch 21/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.6101 - val_loss: 0.5845
# Epoch 22/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5810 - val_loss: 0.5872
# Epoch 23/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5770 - val_loss: 0.5887
# Epoch 24/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5678 - val_loss: 0.5902
# Epoch 25/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5790 - val_loss: 0.6578
# Epoch 26/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.6119 - val_loss: 0.5843
# Epoch 27/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5834 - val_loss: 0.5872
# Epoch 28/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5755 - val_loss: 0.5889
# Epoch 29/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5696 - val_loss: 0.5911
# Epoch 30/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5735 - val_loss: 0.6466
# Epoch 31/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.6122 - val_loss: 0.5842
# Epoch 32/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5855 - val_loss: 0.5853
# Epoch 33/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5753 - val_loss: 0.5884
# Epoch 34/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5704 - val_loss: 0.5860
# Epoch 35/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5717 - val_loss: 0.6358
# Epoch 36/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.6114 - val_loss: 0.5837
# Epoch 37/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5865 - val_loss: 0.5853
# Epoch 38/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5751 - val_loss: 0.5869
# Epoch 39/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5707 - val_loss: 0.5879
# Epoch 40/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5693 - val_loss: 0.6150
# Epoch 41/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.6090 - val_loss: 0.5961
# Epoch 42/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5885 - val_loss: 0.5855
# Epoch 43/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5750 - val_loss: 0.5870
# Epoch 44/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5729 - val_loss: 0.5907
# Epoch 45/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5682 - val_loss: 0.5976
# Epoch 46/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.6021 - val_loss: 0.6149
# Epoch 47/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5947 - val_loss: 0.5850
# Epoch 48/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5744 - val_loss: 0.5853
# Epoch 49/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5749 - val_loss: 0.5905
# Epoch 50/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5670 - val_loss: 0.5903
# Epoch 51/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5939 - val_loss: 0.6282
# Epoch 52/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.6010 - val_loss: 0.5840
# Epoch 53/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5763 - val_loss: 0.5879
# Epoch 54/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5750 - val_loss: 0.5888
# Epoch 55/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5660 - val_loss: 0.5914
# Epoch 56/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5863 - val_loss: 0.6457
# Epoch 57/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.6060 - val_loss: 0.5836
# Epoch 58/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5790 - val_loss: 0.5843
# Epoch 59/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5750 - val_loss: 0.5878
# Epoch 60/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5663 - val_loss: 0.5889
# Epoch 61/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5804 - val_loss: 0.6599
# Epoch 62/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.6097 - val_loss: 0.5833
# Epoch 63/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5808 - val_loss: 0.5847
# Epoch 64/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5753 - val_loss: 0.5867
# Epoch 65/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5666 - val_loss: 0.5876
# Epoch 66/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5753 - val_loss: 0.6545
# Epoch 67/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.6112 - val_loss: 0.5831
# Epoch 68/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5829 - val_loss: 0.5851
# Epoch 69/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5746 - val_loss: 0.5871
# Epoch 70/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5687 - val_loss: 0.5889
# Epoch 71/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5715 - val_loss: 0.6317
# Epoch 72/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.6110 - val_loss: 0.5838
# Epoch 73/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5847 - val_loss: 0.5850
# Epoch 74/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5741 - val_loss: 0.5862
# Epoch 75/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5688 - val_loss: 0.5851
# Epoch 76/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5694 - val_loss: 0.6195
# Epoch 77/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.6107 - val_loss: 0.5828
# Epoch 78/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5862 - val_loss: 0.5843
# Epoch 79/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5735 - val_loss: 0.5858
# Epoch 80/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5711 - val_loss: 0.5872
# Epoch 81/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5680 - val_loss: 0.6032
# Epoch 82/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.6053 - val_loss: 0.6078
# Epoch 83/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5903 - val_loss: 0.5835
# Epoch 84/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5745 - val_loss: 0.5849
# Epoch 85/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5719 - val_loss: 0.5915
# Epoch 86/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5675 - val_loss: 0.5955
# Epoch 87/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5988 - val_loss: 0.6204
# Epoch 88/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5961 - val_loss: 0.5835
# Epoch 89/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5749 - val_loss: 0.5856
# Epoch 90/100
# 500/500 [==============================] - 6s 11ms/step - loss: 0.5747 - val_loss: 0.5882
# Epoch 91/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5649 - val_loss: 0.5876
# Epoch 92/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5913 - val_loss: 0.6362
# Epoch 93/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.6020 - val_loss: 0.5829
# Epoch 94/100
# 500/500 [==============================] - 7s 13ms/step - loss: 0.5773 - val_loss: 0.5858
# Epoch 95/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.5741 - val_loss: 0.5862
# Epoch 96/100
# 500/500 [==============================] - 7s 14ms/step - loss: 0.5654 - val_loss: 0.5887
# Epoch 97/100
# 500/500 [==============================] - 6s 13ms/step - loss: 0.5825 - val_loss: 0.6537
# Epoch 98/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.6083 - val_loss: 0.5827
# Epoch 99/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5784 - val_loss: 0.5836
# Epoch 100/100
# 500/500 [==============================] - 6s 12ms/step - loss: 0.5745 - val_loss: 0.5852
# Train for 500 steps, validate for 100 steps
# Epoch 1/100
# 500/500 [==============================] - 26s 52ms/step - loss: 0.5720 - val_loss: 0.5290
# Epoch 2/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5110 - val_loss: 0.5265
# Epoch 3/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5057 - val_loss: 0.5296
# Epoch 4/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5010 - val_loss: 0.5121
# Epoch 5/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5291 - val_loss: 0.5114
# Epoch 6/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5200 - val_loss: 0.5114
# Epoch 7/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.5057 - val_loss: 0.5163
# Epoch 8/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5040 - val_loss: 0.5254
# Epoch 9/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.4993 - val_loss: 0.5084
# Epoch 10/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.5209 - val_loss: 0.5095
# Epoch 11/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5234 - val_loss: 0.5076
# Epoch 12/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5054 - val_loss: 0.5112
# Epoch 13/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.5045 - val_loss: 0.5161
# Epoch 14/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.4955 - val_loss: 0.5065
# Epoch 15/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.5140 - val_loss: 0.5136
# Epoch 16/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5262 - val_loss: 0.5040
# Epoch 17/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5074 - val_loss: 0.5093
# Epoch 18/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.5028 - val_loss: 0.5109
# Epoch 19/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.4953 - val_loss: 0.5061
# Epoch 20/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5069 - val_loss: 0.5211
# Epoch 21/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.5294 - val_loss: 0.5028
# Epoch 22/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5072 - val_loss: 0.5045
# Epoch 23/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5031 - val_loss: 0.5067
# Epoch 24/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.4949 - val_loss: 0.5036
# Epoch 25/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.5022 - val_loss: 0.5237
# Epoch 26/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5290 - val_loss: 0.5021
# Epoch 27/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.5089 - val_loss: 0.5039
# Epoch 28/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.5019 - val_loss: 0.5045
# Epoch 29/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.4964 - val_loss: 0.5039
# Epoch 30/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.4978 - val_loss: 0.5204
# Epoch 31/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.5282 - val_loss: 0.5008
# Epoch 32/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.5106 - val_loss: 0.5020
# Epoch 33/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.5007 - val_loss: 0.5044
# Epoch 34/100
# 500/500 [==============================] - 18s 35ms/step - loss: 0.4971 - val_loss: 0.5023
# Epoch 35/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.4950 - val_loss: 0.5142
# Epoch 36/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5268 - val_loss: 0.5002
# Epoch 37/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5100 - val_loss: 0.5010
# Epoch 38/100
# 500/500 [==============================] - 18s 35ms/step - loss: 0.5012 - val_loss: 0.5029
# Epoch 39/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.4974 - val_loss: 0.5037
# Epoch 40/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.4942 - val_loss: 0.5129
# Epoch 41/100
# 500/500 [==============================] - 18s 35ms/step - loss: 0.5237 - val_loss: 0.5007
# Epoch 42/100
# 500/500 [==============================] - 18s 35ms/step - loss: 0.5111 - val_loss: 0.5002
# Epoch 43/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.5015 - val_loss: 0.5021
# Epoch 44/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.4977 - val_loss: 0.5054
# Epoch 45/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.4931 - val_loss: 0.5031
# Epoch 46/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5181 - val_loss: 0.5081
# Epoch 47/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5152 - val_loss: 0.5005
# Epoch 48/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5004 - val_loss: 0.5017
# Epoch 49/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.4987 - val_loss: 0.5025
# Epoch 50/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.4922 - val_loss: 0.5012
# Epoch 51/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5121 - val_loss: 0.5226
# Epoch 52/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.5196 - val_loss: 0.4993
# Epoch 53/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5010 - val_loss: 0.5009
# Epoch 54/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.4994 - val_loss: 0.5032
# Epoch 55/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.4913 - val_loss: 0.5025
# Epoch 56/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5056 - val_loss: 0.5315
# Epoch 57/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5227 - val_loss: 0.4988
# Epoch 58/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5027 - val_loss: 0.5001
# Epoch 59/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.4997 - val_loss: 0.5014
# Epoch 60/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.4919 - val_loss: 0.5006
# Epoch 61/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.5000 - val_loss: 0.5459
# Epoch 62/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.5245 - val_loss: 0.4987
# Epoch 63/100
# 500/500 [==============================] - 18s 35ms/step - loss: 0.5046 - val_loss: 0.4996
# Epoch 64/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.4991 - val_loss: 0.5014
# Epoch 65/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.4922 - val_loss: 0.4997
# Epoch 66/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.4966 - val_loss: 0.5431
# Epoch 67/100
# 500/500 [==============================] - 18s 35ms/step - loss: 0.5250 - val_loss: 0.4978
# Epoch 68/100
# 500/500 [==============================] - 18s 35ms/step - loss: 0.5057 - val_loss: 0.4996
# Epoch 69/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.4983 - val_loss: 0.5006
# Epoch 70/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.4948 - val_loss: 0.5003
# Epoch 71/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.4928 - val_loss: 0.5218
# Epoch 72/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5243 - val_loss: 0.4988
# Epoch 73/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5075 - val_loss: 0.4981
# Epoch 74/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.4984 - val_loss: 0.5005
# Epoch 75/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.4946 - val_loss: 0.4994
# Epoch 76/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.4919 - val_loss: 0.5198
# Epoch 77/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5221 - val_loss: 0.4974
# Epoch 78/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5080 - val_loss: 0.4979
# Epoch 79/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.4985 - val_loss: 0.5002
# Epoch 80/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.4954 - val_loss: 0.5024
# Epoch 81/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.4910 - val_loss: 0.5077
# Epoch 82/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5189 - val_loss: 0.5056
# Epoch 83/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5104 - val_loss: 0.4975
# Epoch 84/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.4989 - val_loss: 0.4991
# Epoch 85/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.4953 - val_loss: 0.4998
# Epoch 86/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.4912 - val_loss: 0.5008
# Epoch 87/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5127 - val_loss: 0.5172
# Epoch 88/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5149 - val_loss: 0.4981
# Epoch 89/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.4980 - val_loss: 0.4987
# Epoch 90/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.4980 - val_loss: 0.4989
# Epoch 91/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.4890 - val_loss: 0.5022
# Epoch 92/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.5071 - val_loss: 0.5239
# Epoch 93/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.5182 - val_loss: 0.4968
# Epoch 94/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.5003 - val_loss: 0.4979
# Epoch 95/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.4970 - val_loss: 0.4996
# Epoch 96/100
# 500/500 [==============================] - 18s 35ms/step - loss: 0.4898 - val_loss: 0.4996
# Epoch 97/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.5004 - val_loss: 0.5424
# Epoch 98/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.5219 - val_loss: 0.4962
# Epoch 99/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.5014 - val_loss: 0.4978
# Epoch 100/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.4974 - val_loss: 0.4992

# %%
def plot_train_history(history, title):
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    epochs = range(len(loss))
    
    plt.figure()
    
    plt.plot(epochs, loss, 'b', label='Training Loss')
    plt.plot(epochs, val_loss, 'r', label='Validation Loss')
    plt.xlabel('Epoch')
    plt.title(title)
    plt.legend()
    plt.show()

# %%
plot_train_history(single_step_model_1_history, 'Single Step Model 1 Training and Validation Loss')
plot_train_history(single_step_model_2_history, 'Single Step Model 2 Training and Validation Loss')

# %% [markdown]
# ## Multi Step Model
#
# In a single step setup, the model learns to predict a single point in the future based on history provided
